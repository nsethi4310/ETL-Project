# %%
import pandas as pd
from sqlalchemy import create_engine
#from datetime import datetime
import datetime as dt

# %% [markdown]
# ### Store CSV into DataFrame

# %%
csv_file = "https://raw.githubusercontent.com/nagenderreddy5/ETL-Project/main/NetflixOriginals.csv"
netflix_originals_df = pd.read_csv(csv_file)
netflix_originals_df
# Out:
#                              Title                         Genre  \
# 0                   House of Cards               Political drama
# 1                    Hemlock Grove               Horror/thriller
# 2          Orange Is the New Black                  Comedy-drama
# 3                       Marco Polo              Historical drama
# 4                        Bloodline                      Thriller
# ..                             ...                           ...
# 353                        Busted!  Korean language variety show
# 354   The Break with Michelle Wolf                    Late-night
# 355      Norm Macdonald Has a Show                     Talk show
# 356  Patriot Act with Hasan Minhaj                     Talk show
# 357                        The Fix                    Panel show
#
#                       GenreLabels   Premiere                 Seasons  \
# 0                 political,drama   1-Feb-13  6 seasons, 73 episodes
# 1                 horror,thriller  19-Apr-13  3 seasons, 33 episodes
# 2                    comedy-drama  11-Jul-13  6 seasons, 78 episodes
# 3                historical,drama  12-Dec-14  2 seasons, 20 episodes
# 4                        thriller  20-Mar-15  3 seasons, 33 episodes
# ..                            ...        ...                     ...
# 353  korean,language,variety,show   4-May-18   1 season, 10 episodes
# 354                    late-night  27-May-18   1 season, 10 episodes
# 355                     talk,show  14-Sep-18   1 season, 10 episodes
# 356                     talk,show  28-Oct-18  3 volumes, 19 episodes
# 357                    panel,show  14-Dec-18   1 season, 10 episodes
#
#      SeasonsParsed  EpisodesParsed      Length  MinLength  MaxLength   Status  \
# 0                6              73  42–59 min.         42         59    Ended
# 1                3              33  45–58 min.         45         58    Ended
# 2                6              78  50–92 min.         50         92  Renewed
# 3                2              20  48–65 min.         48         65    Ended
# 4                3              33  48–68 min.         48         68    Ended
# ..             ...             ...         ...        ...        ...      ...
# 353              1              10  75–98 min.         75         98  Renewed
# 354              1              10     27 min.         27         27  Renewed
# 355              1              10  26–35 min.         26         35  Pending
# 356              0              19  23–30 min.         23         30  Renewed
# 357              1              10  23–31 min.         23         31  Pending
#
#      Active        Table Language
# 0         0        Drama  English
# 1         0        Drama  English
# 2         1        Drama  English
# 3         0        Drama  English
# 4         0        Drama  English
# ..      ...          ...      ...
# 353       1  VarietyTalk   Korean
# 354       1  VarietyTalk  English
# 355       1  VarietyTalk  English
# 356       1  VarietyTalk  English
# 357       1  VarietyTalk  English
#
# [358 rows x 14 columns]

# %%
netflix_originals_df.columns
# Out:
# Index(['Title', 'Genre', 'GenreLabels', 'Premiere', 'Seasons', 'SeasonsParsed',
#        'EpisodesParsed', 'Length', 'MinLength', 'MaxLength', 'Status',
#        'Active', 'Table', 'Language'],
#       dtype='object')

# %% [markdown]
# ### Create new data with select columns

# %%
new_netflix_originals_df = netflix_originals_df[['Title', 'Genre', 'Premiere']].copy()
#new_netflix_originals_df = new_netflix_originals_df.reset_index(drop=True, inplace=True)
new_netflix_originals_df
# Out:
#                              Title                         Genre   Premiere
# 0                   House of Cards               Political drama   1-Feb-13
# 1                    Hemlock Grove               Horror/thriller  19-Apr-13
# 2          Orange Is the New Black                  Comedy-drama  11-Jul-13
# 3                       Marco Polo              Historical drama  12-Dec-14
# 4                        Bloodline                      Thriller  20-Mar-15
# ..                             ...                           ...        ...
# 353                        Busted!  Korean language variety show   4-May-18
# 354   The Break with Michelle Wolf                    Late-night  27-May-18
# 355      Norm Macdonald Has a Show                     Talk show  14-Sep-18
# 356  Patriot Act with Hasan Minhaj                     Talk show  28-Oct-18
# 357                        The Fix                    Panel show  14-Dec-18
#
# [358 rows x 3 columns]

# %%
new_netflix_originals_df.columns
# Out:
# Index(['Title', 'Genre', 'Premiere'], dtype='object')

# %%
new_netflix_originals_df['Premiere'] = pd.to_datetime(new_netflix_originals_df['Premiere'], infer_datetime_format=True)
new_netflix_originals_df
# Out:
#                              Title                         Genre   Premiere
# 0                   House of Cards               Political drama 2013-02-01
# 1                    Hemlock Grove               Horror/thriller 2013-04-19
# 2          Orange Is the New Black                  Comedy-drama 2013-07-11
# 3                       Marco Polo              Historical drama 2014-12-12
# 4                        Bloodline                      Thriller 2015-03-20
# ..                             ...                           ...        ...
# 353                        Busted!  Korean language variety show 2018-05-04
# 354   The Break with Michelle Wolf                    Late-night 2018-05-27
# 355      Norm Macdonald Has a Show                     Talk show 2018-09-14
# 356  Patriot Act with Hasan Minhaj                     Talk show 2018-10-28
# 357                        The Fix                    Panel show 2018-12-14
#
# [358 rows x 3 columns]

# %%
start_date = "01-01-2018"
end_date = "12-31-2020"

after_start_date = new_netflix_originals_df["Premiere"] >= start_date
before_end_date = new_netflix_originals_df["Premiere"] <= end_date
between_two_dates = after_start_date & before_end_date
new_netflix_originals_df = new_netflix_originals_df.loc[between_two_dates]

new_netflix_originals_df
# Out:
#                              Title                         Genre   Premiere
# 18                  Altered Carbon               Science fiction 2018-02-02
# 19                   Seven Seconds                   Crime drama 2018-02-23
# 20                   Lost in Space               Science fiction 2018-04-13
# 21                      Insatiable             Dark comedy-drama 2018-08-10
# 22                   The Innocents          Supernatural fiction 2018-08-24
# ..                             ...                           ...        ...
# 353                        Busted!  Korean language variety show 2018-05-04
# 354   The Break with Michelle Wolf                    Late-night 2018-05-27
# 355      Norm Macdonald Has a Show                     Talk show 2018-09-14
# 356  Patriot Act with Hasan Minhaj                     Talk show 2018-10-28
# 357                        The Fix                    Panel show 2018-12-14
#
# [219 rows x 3 columns]

# %%
new_netflix_originals_df['Qtr'] = pd.PeriodIndex(pd.to_datetime(new_netflix_originals_df.Premiere), freq='Q')
new_netflix_originals_df
# Out:
# C:\Users\sethi\Anaconda3\envs\pydata\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                              Title                         Genre   Premiere  \
# 18                  Altered Carbon               Science fiction 2018-02-02
# 19                   Seven Seconds                   Crime drama 2018-02-23
# 20                   Lost in Space               Science fiction 2018-04-13
# 21                      Insatiable             Dark comedy-drama 2018-08-10
# 22                   The Innocents          Supernatural fiction 2018-08-24
# ..                             ...                           ...        ...
# 353                        Busted!  Korean language variety show 2018-05-04
# 354   The Break with Michelle Wolf                    Late-night 2018-05-27
# 355      Norm Macdonald Has a Show                     Talk show 2018-09-14
# 356  Patriot Act with Hasan Minhaj                     Talk show 2018-10-28
# 357                        The Fix                    Panel show 2018-12-14
#
#         Qtr
# 18   2018Q1
# 19   2018Q1
# 20   2018Q2
# 21   2018Q3
# 22   2018Q3
# ..      ...
# 353  2018Q2
# 354  2018Q2
# 355  2018Q3
# 356  2018Q4
# 357  2018Q4
#
# [219 rows x 4 columns]

# %%
new_netflix_originals_df['Years']=new_netflix_originals_df['Qtr'].astype(str).str[-2:] + ' - '+ new_netflix_originals_df['Qtr'].astype(str).str[:4]
new_netflix_originals_df
# Out:
# C:\Users\sethi\Anaconda3\envs\pydata\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                              Title                         Genre   Premiere  \
# 18                  Altered Carbon               Science fiction 2018-02-02
# 19                   Seven Seconds                   Crime drama 2018-02-23
# 20                   Lost in Space               Science fiction 2018-04-13
# 21                      Insatiable             Dark comedy-drama 2018-08-10
# 22                   The Innocents          Supernatural fiction 2018-08-24
# ..                             ...                           ...        ...
# 353                        Busted!  Korean language variety show 2018-05-04
# 354   The Break with Michelle Wolf                    Late-night 2018-05-27
# 355      Norm Macdonald Has a Show                     Talk show 2018-09-14
# 356  Patriot Act with Hasan Minhaj                     Talk show 2018-10-28
# 357                        The Fix                    Panel show 2018-12-14
#
#         Qtr      Years
# 18   2018Q1  Q1 - 2018
# 19   2018Q1  Q1 - 2018
# 20   2018Q2  Q2 - 2018
# 21   2018Q3  Q3 - 2018
# 22   2018Q3  Q3 - 2018
# ..      ...        ...
# 353  2018Q2  Q2 - 2018
# 354  2018Q2  Q2 - 2018
# 355  2018Q3  Q3 - 2018
# 356  2018Q4  Q4 - 2018
# 357  2018Q4  Q4 - 2018
#
# [219 rows x 5 columns]

# %%
new_netflix_originals_df.columns
# Out:
# Index(['Title', 'Genre', 'Premiere', 'Qtr', 'Years'], dtype='object')

# %%
clean_new_netflix_originals_df=new_netflix_originals_df.drop(['Premiere', 'Qtr'], axis=1)
clean_new_netflix_originals_df
# Out:
#                              Title                         Genre      Years
# 18                  Altered Carbon               Science fiction  Q1 - 2018
# 19                   Seven Seconds                   Crime drama  Q1 - 2018
# 20                   Lost in Space               Science fiction  Q2 - 2018
# 21                      Insatiable             Dark comedy-drama  Q3 - 2018
# 22                   The Innocents          Supernatural fiction  Q3 - 2018
# ..                             ...                           ...        ...
# 353                        Busted!  Korean language variety show  Q2 - 2018
# 354   The Break with Michelle Wolf                    Late-night  Q2 - 2018
# 355      Norm Macdonald Has a Show                     Talk show  Q3 - 2018
# 356  Patriot Act with Hasan Minhaj                     Talk show  Q4 - 2018
# 357                        The Fix                    Panel show  Q4 - 2018
#
# [219 rows x 3 columns]

# %%
#clean_new_netflix_originals_df.to_csv(r'C://Users//nagen//OneDrive//Documents//GitHub//GT-ATL-DATA-PT-09-2020-U-C-2//GT-ATL-DATA-PT-09-2020-U-C-2//13-ETL-Project//Resources//Netflix_originals_clean.csv', index = False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-07af54611ee3> in <module>
# ----> 1 clean_new_netflix_originals_df.to_csv(r'C://Users//nagen//OneDrive//Documents//GitHub//GT-ATL-DATA-PT-09-2020-U-C-2//GT-ATL-DATA-PT-09-2020-U-C-2//13-ETL-Project//Resources//Netflix_originals_clean.csv', index = False)
#
# ~\Anaconda3\envs\pydata\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3202             decimal=decimal,
#    3203         )
# -> 3204         formatter.save()
#    3205
#    3206         if path_or_buf is None:
#
# ~\Anaconda3\envs\pydata\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     186                 self.mode,
#     187                 encoding=self.encoding,
# --> 188                 compression=dict(self.compression_args, method=self.compression),
#     189             )
#     190             close = True
#
# ~\Anaconda3\envs\pydata\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     426         if encoding:
#     427             # Encoding
# --> 428             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     429         elif is_text:
#     430             # No explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C://Users//nagen//OneDrive//Documents//GitHub//GT-ATL-DATA-PT-09-2020-U-C-2//GT-ATL-DATA-PT-09-2020-U-C-2//13-ETL-Project//Resources//Netflix_originals_clean.csv'

# %%
netflix_sub_df = pd.read_csv('https://raw.githubusercontent.com/nagenderreddy5/ETL-Project/main/DataNetflixSubscriber2020_V2.csv')
netflix_sub_df.head()
# Out:
#                               Area      Years  Subscribers
# 0         United States and Canada  Q1 - 2018     60909000
# 1  Europe,  Middle East and Africa  Q1 - 2018     29339000
# 2                    Latin America  Q1 - 2018     21260000
# 3                     Asia-Pacific  Q1 - 2018      7394000
# 4         United States and Canada  Q2 - 2018     61870000

# %%
subscriber_df = netflix_sub_df[netflix_sub_df.Area.str.contains('United States and Canada',case=False)]
subscriber_df
# Out:
#                         Area      Years  Subscribers
# 0   United States and Canada  Q1 - 2018     60909000
# 4   United States and Canada  Q2 - 2018     61870000
# 8   United States and Canada  Q3 - 2018     63010000
# 12  United States and Canada  Q4 - 2018     64757000
# 16  United States and Canada  Q1 - 2019     66633000
# 20  United States and Canada  Q2 - 2019     66501000
# 24  United States and Canada  Q3 - 2019     67114000
# 28  United States and Canada  Q4 - 2019     67662000
# 32  United States and Canada  Q1 - 2020     69969000
# 36  United States and Canada  Q2 - 2020     72904000

# %%
subscriber_df.dtypes
# Out:
# Area           object
# Years          object
# Subscribers     int64
# dtype: object

# %%
netflix_rev_df = pd.read_csv('https://raw.githubusercontent.com/nagenderreddy5/ETL-Project/main/DataNetflixRevenue2020_V2.csv')
netflix_rev_df.head()
# Out:
#                               Area      Years     Revenue
# 0         United States and Canada  Q1 - 2018  1976157000
# 1  Europe,  Middle East and Africa  Q1 - 2018   886649000
# 2                    Latin America  Q1 - 2018   540182000
# 3                     Asia-Pacific  Q1 - 2018   199117000
# 4         United States and Canada  Q2 - 2018  2049546000

# %%
revenue_df = netflix_rev_df[netflix_rev_df.Area.str.contains('United States and Canada',case=False)]
revenue_df
# Out:
#                         Area      Years     Revenue
# 0   United States and Canada  Q1 - 2018  1976157000
# 4   United States and Canada  Q2 - 2018  2049546000
# 8   United States and Canada  Q3 - 2018  2094850000
# 12  United States and Canada  Q4 - 2018  2160979000
# 16  United States and Canada  Q1 - 2019  2256851000
# 20  United States and Canada  Q2 - 2019  2501199000
# 24  United States and Canada  Q3 - 2019  2621250000
# 28  United States and Canada  Q4 - 2019  2671908000
# 32  United States and Canada  Q1 - 2020  2702776000
# 36  United States and Canada  Q2 - 2020  2839670000

# %%
revenue_df.dtypes
# Out:
# Area       object
# Years      object
# Revenue     int64
# dtype: object

# %%
combined_df1=pd.merge(clean_new_netflix_originals_df, revenue_df, how='outer', on='Years')
combined_df1.tail(5)
# Out:
#               Title            Genre      Years                      Area  \
# 217      Love Alarm  Romantic comedy  Q3 - 2019  United States and Canada
# 218  The Last Czars      Docu-series  Q3 - 2019  United States and Canada
# 219             NaN              NaN  Q4 - 2019  United States and Canada
# 220             NaN              NaN  Q1 - 2020  United States and Canada
# 221             NaN              NaN  Q2 - 2020  United States and Canada
#
#         Revenue
# 217  2621250000
# 218  2621250000
# 219  2671908000
# 220  2702776000
# 221  2839670000

# %%
clean_combined_df1=combined_df1.dropna()
clean_combined_df1
# Out:
#                   Title                 Genre      Years  \
# 0        Altered Carbon       Science fiction  Q1 - 2018
# 1         Seven Seconds           Crime drama  Q1 - 2018
# 2     Everything Sucks!  Coming-of-age comedy  Q1 - 2018
# 3           On My Block  Coming-of-age comedy  Q1 - 2018
# 4      Devilman Crybaby   Supernatural horror  Q1 - 2018
# ..                  ...                   ...        ...
# 214          Typewriter                Horror  Q3 - 2019
# 215  The Naked Director                 Drama  Q3 - 2019
# 216            Sintonia                 Drama  Q3 - 2019
# 217          Love Alarm       Romantic comedy  Q3 - 2019
# 218      The Last Czars           Docu-series  Q3 - 2019
#
#                          Area     Revenue
# 0    United States and Canada  1976157000
# 1    United States and Canada  1976157000
# 2    United States and Canada  1976157000
# 3    United States and Canada  1976157000
# 4    United States and Canada  1976157000
# ..                        ...         ...
# 214  United States and Canada  2621250000
# 215  United States and Canada  2621250000
# 216  United States and Canada  2621250000
# 217  United States and Canada  2621250000
# 218  United States and Canada  2621250000
#
# [219 rows x 5 columns]

# %%
combined_df2=pd.merge(clean_combined_df1, subscriber_df, how='outer', on=['Area', 'Years'])
combined_df2
# Out:
#                  Title                 Genre      Years  \
# 0       Altered Carbon       Science fiction  Q1 - 2018
# 1        Seven Seconds           Crime drama  Q1 - 2018
# 2    Everything Sucks!  Coming-of-age comedy  Q1 - 2018
# 3          On My Block  Coming-of-age comedy  Q1 - 2018
# 4     Devilman Crybaby   Supernatural horror  Q1 - 2018
# ..                 ...                   ...        ...
# 217         Love Alarm       Romantic comedy  Q3 - 2019
# 218     The Last Czars           Docu-series  Q3 - 2019
# 219                NaN                   NaN  Q4 - 2019
# 220                NaN                   NaN  Q1 - 2020
# 221                NaN                   NaN  Q2 - 2020
#
#                          Area       Revenue  Subscribers
# 0    United States and Canada  1.976157e+09     60909000
# 1    United States and Canada  1.976157e+09     60909000
# 2    United States and Canada  1.976157e+09     60909000
# 3    United States and Canada  1.976157e+09     60909000
# 4    United States and Canada  1.976157e+09     60909000
# ..                        ...           ...          ...
# 217  United States and Canada  2.621250e+09     67114000
# 218  United States and Canada  2.621250e+09     67114000
# 219  United States and Canada           NaN     67662000
# 220  United States and Canada           NaN     69969000
# 221  United States and Canada           NaN     72904000
#
# [222 rows x 6 columns]

# %%
clean_combined_df2=combined_df2.dropna()
clean_combined_df2
# Out:
#                   Title                 Genre      Years  \
# 0        Altered Carbon       Science fiction  Q1 - 2018
# 1         Seven Seconds           Crime drama  Q1 - 2018
# 2     Everything Sucks!  Coming-of-age comedy  Q1 - 2018
# 3           On My Block  Coming-of-age comedy  Q1 - 2018
# 4      Devilman Crybaby   Supernatural horror  Q1 - 2018
# ..                  ...                   ...        ...
# 214          Typewriter                Horror  Q3 - 2019
# 215  The Naked Director                 Drama  Q3 - 2019
# 216            Sintonia                 Drama  Q3 - 2019
# 217          Love Alarm       Romantic comedy  Q3 - 2019
# 218      The Last Czars           Docu-series  Q3 - 2019
#
#                          Area       Revenue  Subscribers
# 0    United States and Canada  1.976157e+09     60909000
# 1    United States and Canada  1.976157e+09     60909000
# 2    United States and Canada  1.976157e+09     60909000
# 3    United States and Canada  1.976157e+09     60909000
# 4    United States and Canada  1.976157e+09     60909000
# ..                        ...           ...          ...
# 214  United States and Canada  2.621250e+09     67114000
# 215  United States and Canada  2.621250e+09     67114000
# 216  United States and Canada  2.621250e+09     67114000
# 217  United States and Canada  2.621250e+09     67114000
# 218  United States and Canada  2.621250e+09     67114000
#
# [219 rows x 6 columns]

# %%
clean_combined_df2.to_csv(r'C://Users//nagen//OneDrive//Documents//GitHub//GT-ATL-DATA-PT-09-2020-U-C-2//GT-ATL-DATA-PT-09-2020-U-C-2//13-ETL-Project//Resources//cleaned_combined_netflixdata.csv', index = False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-23-97004c6f53e9> in <module>
# ----> 1 clean_combined_df2.to_csv(r'C://Users//nagen//OneDrive//Documents//GitHub//GT-ATL-DATA-PT-09-2020-U-C-2//GT-ATL-DATA-PT-09-2020-U-C-2//13-ETL-Project//Resources//cleaned_combined_netflixdata.csv', index = False)
#
# ~\Anaconda3\envs\pydata\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3202             decimal=decimal,
#    3203         )
# -> 3204         formatter.save()
#    3205
#    3206         if path_or_buf is None:
#
# ~\Anaconda3\envs\pydata\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     186                 self.mode,
#     187                 encoding=self.encoding,
# --> 188                 compression=dict(self.compression_args, method=self.compression),
#     189             )
#     190             close = True
#
# ~\Anaconda3\envs\pydata\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     426         if encoding:
#     427             # Encoding
# --> 428             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     429         elif is_text:
#     430             # No explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C://Users//nagen//OneDrive//Documents//GitHub//GT-ATL-DATA-PT-09-2020-U-C-2//GT-ATL-DATA-PT-09-2020-U-C-2//13-ETL-Project//Resources//cleaned_combined_netflixdata.csv'

# %%
rds_connection_string = "postgres:postgres@localhost:5432/Netflix_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['netflix_original', 'netflix_subscriber', 'netflix_revenue']

# %%
subscriber_df.to_sql(name='netflix_subscriber', con=engine, if_exists='append', index=False)

# %%
revenue_df.to_sql(name='netflix_revenue', con=engine, if_exists='append', index=False)

# %%
clean_new_netflix_originals_df.to_sql(name='netflix_original', con=engine, if_exists='append', index=False)

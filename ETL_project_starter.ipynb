# %%
import pandas as pd
from sqlalchemy import create_engine
#from datetime import datetime
import datetime as dt

# %% [markdown]
# ### Store CSV into DataFrame

# %%
csv_file = "C://Users//nagen//OneDrive//Documents//GitHub//GT-ATL-DATA-PT-09-2020-U-C-2//GT-ATL-DATA-PT-09-2020-U-C-2//13-ETL-Project//Resources//NetflixOriginals.csv"
netflix_originals_df = pd.read_csv(csv_file)
netflix_originals_df.head()
# Out:
#                      Title             Genre       GenreLabels   Premiere  \
# 0           House of Cards   Political drama   political,drama   1-Feb-13
# 1            Hemlock Grove   Horror/thriller   horror,thriller  19-Apr-13
# 2  Orange Is the New Black      Comedy-drama      comedy-drama  11-Jul-13
# 3               Marco Polo  Historical drama  historical,drama  12-Dec-14
# 4                Bloodline          Thriller          thriller  20-Mar-15
#
#                   Seasons  SeasonsParsed  EpisodesParsed      Length  \
# 0  6 seasons, 73 episodes              6              73  42–59 min.
# 1  3 seasons, 33 episodes              3              33  45–58 min.
# 2  6 seasons, 78 episodes              6              78  50–92 min.
# 3  2 seasons, 20 episodes              2              20  48–65 min.
# 4  3 seasons, 33 episodes              3              33  48–68 min.
#
#    MinLength  MaxLength   Status  Active  Table Language
# 0         42         59    Ended       0  Drama  English
# 1         45         58    Ended       0  Drama  English
# 2         50         92  Renewed       1  Drama  English
# 3         48         65    Ended       0  Drama  English
# 4         48         68    Ended       0  Drama  English

# %% [markdown]
# ### Create new data with select columns

# %%
new_netflix_originals_df = netflix_originals_df[['Title', 'Genre', 'Premiere']].copy()
#new_netflix_originals_df = new_netflix_originals_df.reset_index(drop=True, inplace=True)
new_netflix_originals_df
# Out:
#                              Title                         Genre   Premiere
# 0                   House of Cards               Political drama   1-Feb-13
# 1                    Hemlock Grove               Horror/thriller  19-Apr-13
# 2          Orange Is the New Black                  Comedy-drama  11-Jul-13
# 3                       Marco Polo              Historical drama  12-Dec-14
# 4                        Bloodline                      Thriller  20-Mar-15
# ..                             ...                           ...        ...
# 353                        Busted!  Korean language variety show   4-May-18
# 354   The Break with Michelle Wolf                    Late-night  27-May-18
# 355      Norm Macdonald Has a Show                     Talk show  14-Sep-18
# 356  Patriot Act with Hasan Minhaj                     Talk show  28-Oct-18
# 357                        The Fix                    Panel show  14-Dec-18
#
# [358 rows x 3 columns]

# %%
new_netflix_originals_df['Premiere'] = pd.to_datetime(new_netflix_originals_df['Premiere'], infer_datetime_format=True)
new_netflix_originals_df
# Out:
#                              Title                         Genre   Premiere
# 0                   House of Cards               Political drama 2013-02-01
# 1                    Hemlock Grove               Horror/thriller 2013-04-19
# 2          Orange Is the New Black                  Comedy-drama 2013-07-11
# 3                       Marco Polo              Historical drama 2014-12-12
# 4                        Bloodline                      Thriller 2015-03-20
# ..                             ...                           ...        ...
# 353                        Busted!  Korean language variety show 2018-05-04
# 354   The Break with Michelle Wolf                    Late-night 2018-05-27
# 355      Norm Macdonald Has a Show                     Talk show 2018-09-14
# 356  Patriot Act with Hasan Minhaj                     Talk show 2018-10-28
# 357                        The Fix                    Panel show 2018-12-14
#
# [358 rows x 3 columns]

# %%
start_date = "2018-01-01"
end_date = "2020-01-31"

after_start_date = new_netflix_originals_df["Premiere"] >= start_date
before_end_date = new_netflix_originals_df["Premiere"] <= end_date
between_two_dates = after_start_date & before_end_date
new_netflix_originals_df = new_netflix_originals_df.loc[between_two_dates]

new_netflix_originals_df
# Out:
#                              Title                         Genre   Premiere
# 18                  Altered Carbon               Science fiction 2018-02-02
# 19                   Seven Seconds                   Crime drama 2018-02-23
# 20                   Lost in Space               Science fiction 2018-04-13
# 21                      Insatiable             Dark comedy-drama 2018-08-10
# 22                   The Innocents          Supernatural fiction 2018-08-24
# ..                             ...                           ...        ...
# 353                        Busted!  Korean language variety show 2018-05-04
# 354   The Break with Michelle Wolf                    Late-night 2018-05-27
# 355      Norm Macdonald Has a Show                     Talk show 2018-09-14
# 356  Patriot Act with Hasan Minhaj                     Talk show 2018-10-28
# 357                        The Fix                    Panel show 2018-12-14
#
# [219 rows x 3 columns]

# %%
#new_netflix_originals_df['Qtr'] = pd.PeriodIndex(pd.to_datetime(new_netflix_originals_df.Premiere), freq='Q')
new_netflix_originals_df['Qtr'] = pd.PeriodIndex(pd.to_datetime(new_netflix_originals_df.Premiere), freq='Q')
new_netflix_originals_df
# Out:
# <ipython-input-16-1e146ca9c414>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_netflix_originals_df['Qtr'] = pd.PeriodIndex(pd.to_datetime(new_netflix_originals_df.Premiere), freq='Q')
#                              Title                         Genre   Premiere  \
# 18                  Altered Carbon               Science fiction 2018-02-02
# 19                   Seven Seconds                   Crime drama 2018-02-23
# 20                   Lost in Space               Science fiction 2018-04-13
# 21                      Insatiable             Dark comedy-drama 2018-08-10
# 22                   The Innocents          Supernatural fiction 2018-08-24
# ..                             ...                           ...        ...
# 353                        Busted!  Korean language variety show 2018-05-04
# 354   The Break with Michelle Wolf                    Late-night 2018-05-27
# 355      Norm Macdonald Has a Show                     Talk show 2018-09-14
# 356  Patriot Act with Hasan Minhaj                     Talk show 2018-10-28
# 357                        The Fix                    Panel show 2018-12-14
#
#         Qtr
# 18   2018Q1
# 19   2018Q1
# 20   2018Q2
# 21   2018Q3
# 22   2018Q3
# ..      ...
# 353  2018Q2
# 354  2018Q2
# 355  2018Q3
# 356  2018Q4
# 357  2018Q4
#
# [219 rows x 4 columns]

# %%
new_netflix_originals_df = new_netflix_originals_df[['Title', 'Genre', 'Qtr']].copy()
new_netflix_originals_df
# Out:
#                              Title                         Genre     Qtr
# 18                  Altered Carbon               Science fiction  2018Q1
# 19                   Seven Seconds                   Crime drama  2018Q1
# 20                   Lost in Space               Science fiction  2018Q2
# 21                      Insatiable             Dark comedy-drama  2018Q3
# 22                   The Innocents          Supernatural fiction  2018Q3
# ..                             ...                           ...     ...
# 353                        Busted!  Korean language variety show  2018Q2
# 354   The Break with Michelle Wolf                    Late-night  2018Q2
# 355      Norm Macdonald Has a Show                     Talk show  2018Q3
# 356  Patriot Act with Hasan Minhaj                     Talk show  2018Q4
# 357                        The Fix                    Panel show  2018Q4
#
# [219 rows x 3 columns]
